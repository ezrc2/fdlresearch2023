# %%
import requests

# %%
# https://www.jcchouinard.com/wikidata-api-python/
def fetch_wikidata(params):
    url = 'https://www.wikidata.org/w/api.php'
    try:
        return requests.get(url, params=params)
    except:
        return 'API error'

# %%
query = 'uiuc'
 
# Which parameters to use
params = {
        'action': 'wbsearchentities',
        'format': 'json',
        'search': query,
        'language': 'en'
    }
 
# Fetch API
json_data = fetch_wikidata(params).json()
json_data
# Out:
# {'searchinfo': {'search': 'uiuc'},
#  'search': [{'id': 'Q457281',
#    'title': 'Q457281',
#    'pageid': 431380,
#    'display': {'label': {'value': 'University of Illinois at Urbana–Champaign',
#      'language': 'en'},
#     'description': {'value': 'public research university in Urbana and Champaign, Illinois, United States',
#      'language': 'en'}},
#    'repository': 'wikidata',
#    'url': '//www.wikidata.org/wiki/Q457281',
#    'concepturi': 'http://www.wikidata.org/entity/Q457281',
#    'label': 'University of Illinois at Urbana–Champaign',
#    'description': 'public research university in Urbana and Champaign, Illinois, United States',
#    'match': {'type': 'alias', 'language': 'en', 'text': 'UIUC'},
#    'aliases': ['UIUC']},
#   {'id': 'Q7895523',
#    'title': 'Q7895523',
#    'pageid': 7833069,
#    'display': {'label': {'value': 'University of Illinois College of Law',
#      'language': 'en'},
#     'description': {'value': 'Law school in Illinois, U.S.',
#      'language': 'en'}},
#    'repository': 'wikidata',
#    'url': '//www.wikidata.org/wiki/Q7895523',
#    'concepturi': 'http://www.wikidata.org/entity/Q7895523',
#    'label': 'University of Illinois College of Law',
#    'description': 'Law school in Illinois, U.S.',
#    'match': {'type': 'alias', 'language': 'en', 'text': 'UIUC Law'},
#    'aliases': ['UIUC Law']},
#   {'id': 'Q7864729',
#    'title': 'Q7864729',
#    'pageid': 7800439,
#    'display': {'label': {'value': 'UIUC College of Media', 'language': 'en'},
#     'description': {'value': 'college at The University of Illinois at Urbana-Champaign',
#      'language': 'en'}},
#    'repository': 'wikidata',
#    'url': '//www.wikidata.org/wiki/Q7864729',
#    'concepturi': 'http://www.wikidata.org/entity/Q7864729',
#    'label': 'UIUC College of Media',
#    'description': 'college at The University of Illinois at Urbana-Champaign',
#    'match': {'type': 'label',
#     'language': 'en',
#     'text': 'UIUC College of Media'}},
#   {'id': 'Q7864725',
#    'title': 'Q7864725',
#    'pageid': 7800435,
#    'display': {'label': {'value': 'Grainger College of Engineering',
#      'language': 'en'},
#     'description': {'value': 'Original unit of the University of Illinois',
#      'language': 'en'}},
#    'repository': 'wikidata',
#    'url': '//www.wikidata.org/wiki/Q7864725',
#    'concepturi': 'http://www.wikidata.org/entity/Q7864725',
#    'label': 'Grainger College of Engineering',
#    'description': 'Original unit of the University of Illinois',
#    'match': {'type': 'alias',
#     'language': 'en',
#     'text': 'UIUC College of Engineering'},
#    'aliases': ['UIUC College of Engineering']},
#   {'id': 'Q7864726',
#    'title': 'Q7864726',
#    'pageid': 7800436,
#    'display': {'label': {'value': 'University of Illinois College of Fine and Applied Arts',
#      'language': 'en'},
#     'description': {'value': 'college in Illinois, U.S.', 'language': 'en'}},
#    'repository': 'wikidata',
#    'url': '//www.wikidata.org/wiki/Q7864726',
#    'concepturi': 'http://www.wikidata.org/entity/Q7864726',
#    'label': 'University of Illinois College of Fine and Applied Arts',
#    'description': 'college in Illinois, U.S.',
#    'match': {'type': 'alias',
#     'language': 'en',
#     'text': 'UIUC College of Fine and Applied Arts'},
#    'aliases': ['UIUC College of Fine and Applied Arts']},
#   {'id': 'Q2495855',
#    'title': 'Q2495855',
#    'pageid': 2409396,
#    'display': {'label': {'value': 'University of Illinois/NCSA Open Source License',
#      'language': 'en'},
#     'description': {'value': 'lax permissive free software license',
#      'language': 'en'}},
#    'repository': 'wikidata',
#    'url': '//www.wikidata.org/wiki/Q2495855',
#    'concepturi': 'http://www.wikidata.org/entity/Q2495855',
#    'label': 'University of Illinois/NCSA Open Source License',
#    'description': 'lax permissive free software license',
#    'match': {'type': 'alias', 'language': 'en', 'text': 'UIUC license'},
#    'aliases': ['UIUC license']},
#   {'id': 'Q7864730',
#    'title': 'Q7864730',
#    'pageid': 7800440,
#    'display': {'label': {'value': 'UIUC College of Veterinary Medicine',
#      'language': 'en'}},
#    'repository': 'wikidata',
#    'url': '//www.wikidata.org/wiki/Q7864730',
#    'concepturi': 'http://www.wikidata.org/entity/Q7864730',
#    'label': 'UIUC College of Veterinary Medicine',
#    'match': {'type': 'label',
#     'language': 'en',
#     'text': 'UIUC College of Veterinary Medicine'}}],
#  'search-continue': 7,
#  'success': 1}

# %%
# for elem in data['search']:
#     print(elem['id'])

# %%
id_ = json_data['search'][0]['id']
params = {
            'action': 'wbgetentities',
            'ids': id_, 
            'format': 'json',
            'languages': 'en'
        }
 
# fetch the API
data = fetch_wikidata(params)
 
# Show response
data = data.json()
data
# Out:
# {'entities': {'Q457281': {'pageid': 431380,
#    'ns': 0,
#    'title': 'Q457281',
#    'lastrevid': 1916576797,
#    'modified': '2023-06-16T13:19:33Z',
#    'type': 'item',
#    'id': 'Q457281',
#    'labels': {'en': {'language': 'en',
#      'value': 'University of Illinois at Urbana–Champaign'}},
#    'descriptions': {'en': {'language': 'en',
#      'value': 'public research university in Urbana and Champaign, Illinois, United States'}},
#    'aliases': {'en': [{'language': 'en', 'value': 'UIUC'},
#      {'language': 'en', 'value': 'U of I'},
#      {'language': 'en', 'value': 'University of Illinois at Urbana'},
#      {'language': 'en', 'value': 'University of Illinois at Champaign'},
#      {'language': 'en', 'value': 'University of Illinois at Champaign-Urbana'},
#      {'language': 'en', 'value': 'University of Illinois at Urbana-Champaign'},
#      {'language': 'en', 'value': 'University of Illinois'},
#      {'language': 'en', 'value': 'U. of I.'},
#      {'language': 'en', 'value': 'uiuc.edu'},
#      {'language': 'en', 'value': 'University of Illinois Urbana-Champaign'},
#      {'language': 'en', 'value': 'University of Illinois, Urbana-Champaign'}]},
#    'claims': {'P373': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P373',
#        'hash': 'cf9c89f41a0caa509c6bee0142999d041bcca9ff',
#        'datavalue': {'value': 'University of Illinois at Urbana–Champaign',
#         'type': 'string'},
#        'datatype': 'string'},
#       'type': 'statement',
#       'id': 'q457281$2011D5D3-143A-4B66-90CD-437E0DB8AF83',
#       'rank': 'normal'}],
#     'P31': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P31',
#        'hash': 'b936086d3ba325db2743ffd1acccaae93509f356',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 62078547,
#          'id': 'Q62078547'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'q457281$06496311-E9A2-4EA9-9E9D-A7E19F9DEF2B',
#       'rank': 'normal',
#       'references': [{'hash': '00acd277aa845c674d8cb974b1873349cee44aa4',
#         'snaks': {'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': '1778acec9d18a7285eefb8ae0c0401f8c773ed02',
#            'datavalue': {'value': {'time': '+2019-03-16T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P813']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P31',
#        'hash': 'e92aa517812d04d5d07672de51bed291e65cb7fd',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 615150,
#          'id': 'Q615150'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q457281$0BD231F2-0B5F-4866-B57E-7381B85595A3',
#       'rank': 'normal',
#       'references': [{'hash': '3a898e189b5a0c811a5d4ee8eeab4639efe4b6e1',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': 'de023d0250f2da0b78b75da8b0d774c678641334',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 6042926,
#              'id': 'Q6042926'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P248']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P31',
#        'hash': 'f86cd0813c2de2adf2f7ff53830e2169f779851a',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 23002039,
#          'id': 'Q23002039'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q457281$14D38C40-6079-4BD1-8735-FDBA60FA986B',
#       'rank': 'normal',
#       'references': [{'hash': '3a898e189b5a0c811a5d4ee8eeab4639efe4b6e1',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': 'de023d0250f2da0b78b75da8b0d774c678641334',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 6042926,
#              'id': 'Q6042926'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P248']}]}],
#     'P17': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P17',
#        'hash': 'be4c6eafa2984964f04be85667263f5642ba1a72',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 30,
#          'id': 'Q30'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'q457281$1B6EB081-BD2A-48BD-B85A-AC7E785042E2',
#       'rank': 'normal',
#       'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#         'snaks': {'P143': [{'snaktype': 'value',
#            'property': 'P143',
#            'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 328,
#              'id': 'Q328'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P143']}]}],
#     'P131': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P131',
#        'hash': '5c62998320c74130f7f57a8fef34ff002b0f3f8f',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 577964,
#          'id': 'Q577964'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'q457281$24498D2C-0583-48E9-8D13-35B16F3D48A4',
#       'rank': 'normal'}],
#     'P910': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P910',
#        'hash': 'c327dd23d7a9b2ae9462169a252e29ceca06e874',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 8055789,
#          'id': 'Q8055789'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q457281$B6CB26CF-7DCE-4445-9C29-B10BC4A8CCCE',
#       'rank': 'normal'}],
#     'P18': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P18',
#        'hash': '0678965e990acb3728a6b475f3fb85fd92d7d478',
#        'datavalue': {'value': 'UIUC Illini Union and Main Quad.jpg',
#         'type': 'string'},
#        'datatype': 'commonsMedia'},
#       'type': 'statement',
#       'id': 'Q457281$CEBB519A-9CD8-47C0-BDFB-E558182FB128',
#       'rank': 'normal'}],
#     'P646': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P646',
#        'hash': 'b3c2b2036f78653e5e863b053f27b25391b99462',
#        'datavalue': {'value': '/m/0220q6', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q457281$5CE60118-7C8C-4E46-A06D-397DB866E8A7',
#       'rank': 'normal',
#       'references': [{'hash': '2b00cb481cddcac7623114367489b5c194901c4a',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': 'a94b740202b097dd33355e0e6c00e54b9395e5e0',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 15241312,
#              'id': 'Q15241312'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P577': [{'snaktype': 'value',
#            'property': 'P577',
#            'hash': 'fde79ecb015112d2f29229ccc1ec514ed3e71fa2',
#            'datavalue': {'value': {'time': '+2013-10-28T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P248', 'P577']}]}],
#     'P463': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P463',
#        'hash': '2961d653cf3e948221cc84f6d2ba3fb0f98a7c8d',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 729478,
#          'id': 'Q729478'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q457281$C5332BB7-13C1-4FAC-9B6D-74A1386F5BE0',
#       'rank': 'normal',
#       'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#         'snaks': {'P143': [{'snaktype': 'value',
#            'property': 'P143',
#            'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 328,
#              'id': 'Q328'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P143']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P463',
#        'hash': '75786e71fb1fff498aef84f9e016bbd3fd0afdb6',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 19861084,
#          'id': 'Q19861084'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q457281$EC579328-A226-4E28-A40B-2CD56810DBB4',
#       'rank': 'normal',
#       'references': [{'hash': '3a0c339226ea7043bd8521b87880214a0ec994d0',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': '2e3fa79ba0c807b4993f3b7a977acbf0d1c7d85b',
#            'datavalue': {'value': 'https://orcid.org/members/001G000001KKCzlIAH-university-of-illinois-at-urbana-champaign',
#             'type': 'string'},
#            'datatype': 'url'}]},
#         'snaks-order': ['P854']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P463',
#        'hash': 'dad4bc05f9610ae79ec5cfb7de65152292adb802',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 5275906,
#          'id': 'Q5275906'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q457281$87F1C6CB-4CC0-4469-B001-444EC88E83A5',
#       'rank': 'normal',
#       'references': [{'hash': '33df96fbb2b98b19adbe1148e8b50ad1def34dd7',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': 'fea817de8f94d104f86e59691b7bfea7562d6129',
#            'datavalue': {'value': 'https://www.clir.org/about/current-sponsors-and-funders',
#             'type': 'string'},
#            'datatype': 'url'}]},
#         'snaks-order': ['P854']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P463',
#        'hash': 'de8e9061bef77e0ac2100f2f174b084fe68ca6ce',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 4810036,
#          'id': 'Q4810036'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q457281$8ABEA6AE-ADDC-40CA-BB91-CB6EFC72E8BB',
#       'rank': 'normal',
#       'references': [{'hash': '5a9ee08a67295032d11ca0f1c78ceb5d6664af44',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': 'b0d7bb697a4e48a7d2fe57acd3394af475cdd4d2',
#            'datavalue': {'value': 'http://old.arl.org/arl/membership/members.shtml',
#             'type': 'string'},
#            'datatype': 'url'}]},
#         'snaks-order': ['P854']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P463',
#        'hash': '33c92f609e55a96b4fc6302dc23f0bed6cfebfbb',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 5153069,
#          'id': 'Q5153069'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q457281$6883850d-44e5-2e47-4de2-b427ae2c66da',
#       'rank': 'normal',
#       'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#         'snaks': {'P143': [{'snaktype': 'value',
#            'property': 'P143',
#            'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 328,
#              'id': 'Q328'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P143']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P463',
#        'hash': 'b98f5625211374836e8c4217885c167031f01fb0',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 37033,
#          'id': 'Q37033'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q457281$cfab01eb-4af6-a9d7-718c-daf40253f2f4',
#       'rank': 'normal',
#       'references': [{'hash': '814498269cf5e4483d8cfb7ba674e37836fcfe1d',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': '37f92859f2ebed73ed4d54de53932ac988fee1db',
#            'datavalue': {'value': 'https://www.w3.org/Consortium/Member/List',
#             'type': 'string'},
#            'datatype': 'url'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': '949efbe5702752b27a649957870d9223e727bfde',
#            'datavalue': {'value': {'time': '+2019-05-23T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P854', 'P813']},
#        {'hash': '2355ecfcfcf0bd9ed578c1c38a70bcf7f38c464b',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': '37f92859f2ebed73ed4d54de53932ac988fee1db',
#            'datavalue': {'value': 'https://www.w3.org/Consortium/Member/List',
#             'type': 'string'},
#            'datatype': 'url'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': '9340d2d6ac4166f53327cfcd01967f24799356e7',
#            'datavalue': {'value': {'time': '+2019-06-11T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P854', 'P813']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P463',
#        'hash': 'd26ebcd9de65163511000fcfc8e855742f90b858',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 5137944,
#          'id': 'Q5137944'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q457281$08DEAE10-6EF7-4319-9E0E-99D58F670DC3',
#       'rank': 'normal',
#       'references': [{'hash': 'd6d20f501cfc9ae68a4aee614559638464bce937',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': '21138cfbd96eef3b3247f251ff4658c05d1c0136',
#            'datavalue': {'value': 'https://web.archive.org/web/20200122180935/https://www.cni.org/about-cni/membership/members',
#             'type': 'string'},
#            'datatype': 'url'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': '48b0cdabfeba46701972810a9bcc670cab15ff4e',
#            'datavalue': {'value': {'time': '+2020-01-22T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P854', 'P813']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P463',
#        'hash': 'db363dc7c458681133584c54da5834c81686e663',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 101483295,
#          'id': 'Q101483295'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q457281$800C3BC1-C95B-4CB5-AABA-9963D8C87B96',
#       'rank': 'normal',
#       'references': [{'hash': 'c42c17cd56007853be4be3aaca29426fdc7cbf21',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': '21dd58e1f58c7e716ea30df100c53f81536317d1',
#            'datavalue': {'value': 'https://www.cossa.org/members/',
#             'type': 'string'},
#            'datatype': 'url'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': 'df8141fe5857b3abb15525a8215307e8e7e75012',
#            'datavalue': {'value': {'time': '+2020-11-09T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P854', 'P813']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P463',
#        'hash': 'f58dc6d17064f7c4cf95bb7b3e95a8bf31e8c600',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 108872504,
#          'id': 'Q108872504'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q457281$431F6AED-31F8-47B2-BA4D-B8C9BCAB27BA',
#       'rank': 'normal',
#       'references': [{'hash': 'b0b23898d57e7cc2940991fc7610d4a1a32b11d9',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': '77ef900e334162fae8bae1c02f80f8cb879b774e',
#            'datavalue': {'value': 'https://datadryad.org/stash/our_community',
#             'type': 'string'},
#            'datatype': 'url'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': 'a71d55516c385c58d0f86f5178be1cd6231c9ea9',
#            'datavalue': {'value': {'time': '+2021-10-18T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P854', 'P813']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P463',
#        'hash': '57f2a0ba0f88c4b42834d3fa76617b9c1ff9c490',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 118398,
#          'id': 'Q118398'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'qualifiers': {'P585': [{'snaktype': 'value',
#          'property': 'P585',
#          'hash': '4a6fe7f861358928efef462e361b21704446d129',
#          'datavalue': {'value': {'time': '+2021-00-00T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 9,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'qualifiers-order': ['P585'],
#       'id': 'Q457281$9CC0AE9A-3BD8-4282-8CE3-CC8071A98C90',
#       'rank': 'normal',
#       'references': [{'hash': 'e1febaef03f5eb9bbde48e1ff60c6e1e0a159d8a',
#         'snaks': {'P1476': [{'snaktype': 'value',
#            'property': 'P1476',
#            'hash': '0f151f0dce19d4ea80e3290809f42904a61a5057',
#            'datavalue': {'value': {'text': 'Our Members / Tier 1',
#              'language': 'en'},
#             'type': 'monolingualtext'},
#            'datatype': 'monolingualtext'}],
#          'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': '9e787a799496366a6f3d4bce212c1f85c0fb60f4',
#            'datavalue': {'value': 'https://web.archive.org/web/20211129171645/https://arxiv.org/about/ourmembers',
#             'type': 'string'},
#            'datatype': 'url'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': '2cc4dc60d7d758167201cd0c2140452382b68a41',
#            'datavalue': {'value': {'time': '+2021-11-00T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 10,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P1476', 'P854', 'P813']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P463',
#        'hash': '0155824815870050937a5c9b69d1a76bd5ec8301',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 5275956,
#          'id': 'Q5275956'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'qualifiers': {'P580': [{'snaktype': 'value',
#          'property': 'P580',
#          'hash': 'e18d3ba7a83b3a85bc3146e03813224f03817c66',
#          'datavalue': {'value': {'time': '+2023-00-00T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 9,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'qualifiers-order': ['P580'],
#       'id': 'Q457281$2d312a40-4780-f26f-4866-f6ff91669d84',
#       'rank': 'normal',
#       'references': [{'hash': 'b13d9b91c83be29470e87c761e802efdd4168097',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': '52e2645d86a917fc6f09fbc51bdadb2bea7ca50a',
#            'datavalue': {'value': 'https://www.dpconline.org/news/new-members-of-the-dpc/university-of-illinois-at-urbana-champaign-becomes-the-digital-preservation-coalition-s-newest-full-member',
#             'type': 'string'},
#            'datatype': 'url'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': '5b499aa82f71cb7ccd6fb86d66a4395d30ba5927',
#            'datavalue': {'value': {'time': '+2023-02-22T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P854', 'P813']}]}],
#     'P856': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P856',
#        'hash': '75e9a1c244cbc2508d68e5a714c58e62262a9031',
#        'datavalue': {'value': 'https://illinois.edu/', 'type': 'string'},
#        'datatype': 'url'},
#       'type': 'statement',
#       'qualifiers': {'P407': [{'snaktype': 'value',
#          'property': 'P407',
#          'hash': 'daf1c4fcb58181b02dff9cc89deb084004ddae4b',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 1860,
#            'id': 'Q1860'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'qualifiers-order': ['P407'],
#       'id': 'Q457281$C08F9206-0709-4643-B873-2D4AFEDDB7C2',
#       'rank': 'normal'}],
#     'P214': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P214',
#        'hash': '928678f96111edc1f4b169b09a1dc712ca235195',
#        'datavalue': {'value': '158181260', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'qualifiers': {'P2241': [{'snaktype': 'value',
#          'property': 'P2241',
#          'hash': '0fb315c434ea232f342862abded9b726ce9b6bf6',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 54975531,
#            'id': 'Q54975531'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'qualifiers-order': ['P2241'],
#       'id': 'Q457281$8C504200-EBB3-4524-BEAC-0AD2A48373C5',
#       'rank': 'deprecated',
#       'references': [{'hash': 'ffb7008c3b41d9efd69c450e837f49eebb1b6dce',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '6b7d4330c4aac4caec4ede9de0311ce273f88ecd',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 54919,
#              'id': 'Q54919'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': '76142c1ac740096f18ea230da7fb62353d1c531f',
#            'datavalue': {'value': {'time': '+2015-08-03T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P248', 'P813']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P214',
#        'hash': '045bb5d437813d7f23abb13a2a0d2a60d4530a39',
#        'datavalue': {'value': '153024823', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q457281$e6a45405-44a5-66e4-7099-5fa6668fcc75',
#       'rank': 'normal'}],
#     'P1771': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P1771',
#        'hash': '0b33cb92e64dd337c2646662a42d5f2bfb455a62',
#        'datavalue': {'value': '145637', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q457281$E89F7EF8-24A1-44C2-BFCF-7B18F401636E',
#       'rank': 'normal',
#       'references': [{'hash': 'cfc3fc925ddc31f71c67244753346f9fca7ab7d7',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': 'a94b740202b097dd33355e0e6c00e54b9395e5e0',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 15241312,
#              'id': 'Q15241312'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P248']}]}],
#     'P268': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P268',
#        'hash': '9198d2fe30c7b5325e5537d7289eff63ec4f9274',
#        'datavalue': {'value': '118838604', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q457281$D6E4B36C-8D8C-4C6F-A6F2-41C316731CC9',
#       'rank': 'normal',
#       'references': [{'hash': '4533e325b4161189dcba02b6a92f6c4533327637',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '6b7d4330c4aac4caec4ede9de0311ce273f88ecd',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 54919,
#              'id': 'Q54919'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': 'a5fb6c3872e96e7c068b0826ff7393eaba0e8fc3',
#            'datavalue': {'value': {'time': '+2015-10-06T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P248', 'P813']}]}],
#     'P269': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P269',
#        'hash': '27bff9055d33cf4398bf86db4a3b76c1e5327867',
#        'datavalue': {'value': '026627809', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q457281$CB0144E9-5027-4A9D-A85C-E0600AC4C310',
#       'rank': 'normal',
#       'references': [{'hash': '4533e325b4161189dcba02b6a92f6c4533327637',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '6b7d4330c4aac4caec4ede9de0311ce273f88ecd',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 54919,
#              'id': 'Q54919'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': 'a5fb6c3872e96e7c068b0826ff7393eaba0e8fc3',
#            'datavalue': {'value': {'time': '+2015-10-06T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P248', 'P813']}]}],
#     'P571': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P571',
#        'hash': 'ee19b12de4fef8cd0e39d31bea3310e83360c140',
#        'datavalue': {'value': {'time': '+1867-00-00T00:00:00Z',
#          'timezone': 0,
#          'before': 0,
#          'after': 0,
#          'precision': 9,
#          'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#         'type': 'time'},
#        'datatype': 'time'},
#       'type': 'statement',
#       'id': 'Q457281$7C633846-CAB6-42ED-AEFE-A53F6560C089',
#       'rank': 'normal',
#       'references': [{'hash': '9a24f7c0208b05d6be97077d855671d1dfdbc0dd',
#         'snaks': {'P143': [{'snaktype': 'value',
#            'property': 'P143',
#            'hash': 'd38375ffe6fe142663ff55cd783aa4df4301d83d',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 48183,
#              'id': 'Q48183'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P143']}]}],
#     'P281': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P281',
#        'hash': 'a54fecbc15ee28c4211e21126e48849726e3bd1b',
#        'datavalue': {'value': '61820-5711', 'type': 'string'},
#        'datatype': 'string'},
#       'type': 'statement',
#       'id': 'Q457281$3FBDA434-7304-41DF-A6C1-5798A14A3003',
#       'rank': 'normal',
#       'references': [{'hash': '3a898e189b5a0c811a5d4ee8eeab4639efe4b6e1',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': 'de023d0250f2da0b78b75da8b0d774c678641334',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 6042926,
#              'id': 'Q6042926'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P248']}]}],
#     'P2002': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P2002',
#        'hash': '2e0ce0d4d860830fa180bf988f19a7ba33aeed0d',
#        'datavalue': {'value': 'Illinois_Alma', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'qualifiers': {'P3744': [{'snaktype': 'value',
#          'property': 'P3744',
#          'hash': 'f6b31066217ebd2790a40dc5ed725ba864b99e07',
#          'datavalue': {'value': {'amount': '+82746', 'unit': '1'},
#           'type': 'quantity'},
#          'datatype': 'quantity'}],
#        'P6552': [{'snaktype': 'value',
#          'property': 'P6552',
#          'hash': '5f99e536f4d7e2fe3ac7fda87386ed262907e9ce',
#          'datavalue': {'value': '18165866', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P1552': [{'snaktype': 'value',
#          'property': 'P1552',
#          'hash': '62f0039d240f7eeba6c6908a0d8807a6188324a1',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 28378282,
#            'id': 'Q28378282'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P580': [{'snaktype': 'value',
#          'property': 'P580',
#          'hash': '205bf2acc2372fac7e7af37c8aadabd05cb4c408',
#          'datavalue': {'value': {'time': '+2008-12-16T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}],
#        'P585': [{'snaktype': 'value',
#          'property': 'P585',
#          'hash': 'd23772ed2b8b4c4e31ec158c814140af0379c572',
#          'datavalue': {'value': {'time': '+2020-04-25T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'qualifiers-order': ['P3744', 'P6552', 'P1552', 'P580', 'P585'],
#       'id': 'Q457281$bb63f8c8-47cd-97a9-85c3-970b1dbac09f',
#       'rank': 'normal',
#       'references': [{'hash': '830e0d3d65e6b91e769889d7d1177706b5c1e0ca',
#         'snaks': {'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': 'cd8210fc3215a6112ebad72d11663d1a56b14d67',
#            'datavalue': {'value': {'time': '+2018-05-10T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P813']}]}],
#     'P1332': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P1332',
#        'hash': 'bf92a4f0e80055b5b98d4bff1c45c08085bb3794',
#        'datavalue': {'value': {'latitude': 40.1163,
#          'longitude': -88.22632,
#          'altitude': None,
#          'precision': 1e-05,
#          'globe': 'http://www.wikidata.org/entity/Q2'},
#         'type': 'globecoordinate'},
#        'datatype': 'globe-coordinate'},
#       'type': 'statement',
#       'id': 'Q457281$30794485-4b36-d9ad-27ee-3b182b281a87',
#       'rank': 'normal'}],
#     'P1333': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P1333',
#        'hash': '2cb7d8be59cd95ceb3c9cc110c0489ef07a565bf',
#        'datavalue': {'value': {'latitude': 40.091080555556,
#          'longitude': -88.226319444444,
#          'altitude': None,
#          'precision': 2.7777777777778e-06,
#          'globe': 'http://www.wikidata.org/entity/Q2'},
#         'type': 'globecoordinate'},
#        'datatype': 'globe-coordinate'},
#       'type': 'statement',
#       'id': 'Q457281$55d94709-4bde-fb82-8f91-bbdebbc29efc',
#       'rank': 'normal'}],
#     'P1334': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P1334',
#        'hash': '2d9d3baf8914e15cfe339834e76a17808ff0f3e2',
#        'datavalue': {'value': {'latitude': 40.09609,
#          'longitude': -88.21953,
#          'altitude': None,
#          'precision': 1e-05,
#          'globe': 'http://www.wikidata.org/entity/Q2'},
#         'type': 'globecoordinate'},
#        'datatype': 'globe-coordinate'},
#       'type': 'statement',
#       'id': 'Q457281$6dc29f6b-4bbc-4e28-4c0f-4b312cb17aaf',
#       'rank': 'normal'}],
#     'P1335': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P1335',
#        'hash': 'b1a8ebbeb1baa2370215f53784d71ffd2957979c',
#        'datavalue': {'value': {'latitude': 40.096088888889,
#          'longitude': -88.244088888889,
#          'altitude': None,
#          'precision': 2.7777777777778e-06,
#          'globe': 'http://www.wikidata.org/entity/Q2'},
#         'type': 'globecoordinate'},
#        'datatype': 'globe-coordinate'},
#       'type': 'statement',
#       'id': 'Q457281$f2405df5-4499-bccb-03b0-08c55a53500a',
#       'rank': 'normal'}],
#     'P625': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P625',
#        'hash': '047ae88f239a30430ff99597a3686758ee88c143',
#        'datavalue': {'value': {'latitude': 40.110538888889,
#          'longitude': -88.228411111111,
#          'altitude': None,
#          'precision': 2.7777777777778e-06,
#          'globe': 'http://www.wikidata.org/entity/Q2'},
#         'type': 'globecoordinate'},
#        'datatype': 'globe-coordinate'},
#       'type': 'statement',
#       'id': 'Q457281$7059c6d5-4cc6-21f7-5a60-1e98ce2dedc0',
#       'rank': 'normal',
#       'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#         'snaks': {'P143': [{'snaktype': 'value',
#            'property': 'P143',
#            'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 328,
#              'id': 'Q328'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P143']}]}],
#     'P2643': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P2643',
#        'hash': 'ee1f4a6dbb931f1e6bef4f20ebfd36919be29f04',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 23334765,
#          'id': 'Q23334765'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q457281$E0C61E0B-A89E-4E3F-A439-48894134F96A',
#       'rank': 'normal',
#       'references': [{'hash': '0c1a8ae6ad3b8fb4f373c533150355a20f759090',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '46652cd7969b7b2eb09c38cb36bf2d2effe4ae5a',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 4223026,
#              'id': 'Q4223026'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P248']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P2643',
#        'hash': 'eed29ce0f5a46fd7e6c75784bb54b0d3ce4b2677',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 23623483,
#          'id': 'Q23623483'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q457281$1744D40D-7634-4F6E-82DF-655158DDD074',
#       'rank': 'normal',
#       'references': [{'hash': '0c1a8ae6ad3b8fb4f373c533150355a20f759090',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '46652cd7969b7b2eb09c38cb36bf2d2effe4ae5a',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 4223026,
#              'id': 'Q4223026'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P248']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P2643',
#        'hash': '528b911150271e3d955d12eb65125ac3590e11b8',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 23662486,
#          'id': 'Q23662486'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q457281$AFAF724A-F51C-45CB-9875-308CFB8D37C1',
#       'rank': 'normal',
#       'references': [{'hash': '0c1a8ae6ad3b8fb4f373c533150355a20f759090',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '46652cd7969b7b2eb09c38cb36bf2d2effe4ae5a',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 4223026,
#              'id': 'Q4223026'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P248']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P2643',
#        'hash': '0c0483ae216f7a5257fbf96c3b1816abe5859537',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 23622771,
#          'id': 'Q23622771'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q457281$5951BEE8-DBED-4BDF-91DE-946396EDB892',
#       'rank': 'normal',
#       'references': [{'hash': '0c1a8ae6ad3b8fb4f373c533150355a20f759090',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '46652cd7969b7b2eb09c38cb36bf2d2effe4ae5a',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 4223026,
#              'id': 'Q4223026'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P248']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P2643',
#        'hash': 'eea0492887eea09d4ed559bd7ee82bbf58d74f41',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 23662432,
#          'id': 'Q23662432'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q457281$8A80E868-43E3-4B26-B865-08ABB1BF6362',
#       'rank': 'normal',
#       'references': [{'hash': '0c1a8ae6ad3b8fb4f373c533150355a20f759090',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '46652cd7969b7b2eb09c38cb36bf2d2effe4ae5a',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 4223026,
#              'id': 'Q4223026'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P248']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P2643',
#        'hash': '1456fd12bdef36ba43bceda4a616c5645beba537',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 23662768,
#          'id': 'Q23662768'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q457281$675B2013-3BD6-43CB-8571-BE2D5EC18D18',
#       'rank': 'normal',
#       'references': [{'hash': '0c1a8ae6ad3b8fb4f373c533150355a20f759090',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '46652cd7969b7b2eb09c38cb36bf2d2effe4ae5a',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 4223026,
#              'id': 'Q4223026'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P248']}]}],
#     'P998': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P998',
#        'hash': 'ec260888a144e4322b1b28e3d656f2a9b5a68b8d',
#        'datavalue': {'value': 'Reference/Education/Colleges_and_Universities/North_America/United_States/Illinois/University_of_Illinois/Urbana-Champaign/',
#         'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q457281$d6ca6607-4f53-bda4-f395-1972c3188a41',
#       'rank': 'normal'}],
#     'P227': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P227',
#        'hash': 'c2ef3b06c56a8d985598eeb2a7fed303a06b07f4',
#        'datavalue': {'value': '2045531-8', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q457281$A05236B8-AE3A-48D7-A3BE-F4715BB055DA',
#       'rank': 'normal',
#       'references': [{'hash': '9a24f7c0208b05d6be97077d855671d1dfdbc0dd',
#         'snaks': {'P143': [{'snaktype': 'value',
#            'property': 'P143',
#            'hash': 'd38375ffe6fe142663ff55cd783aa4df4301d83d',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 48183,
#              'id': 'Q48183'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P143']}]}],
#     'P749': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P749',
#        'hash': 'e775400109638883aafd8969f0d5622925638292',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 1145814,
#          'id': 'Q1145814'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q457281$1a4a3245-4c15-2316-40d2-4abba70234c2',
#       'rank': 'normal',
#       'references': [{'hash': '4db8968b5d256ca6cd43875262755421c08592ba',
#         'snaks': {'P2427': [{'snaktype': 'value',
#            'property': 'P2427',
#            'hash': '77bd818abe217dc7dff9247e879c3c01d873194a',
#            'datavalue': {'value': 'grid.35403.31', 'type': 'string'},
#            'datatype': 'external-id'}]},
#         'snaks-order': ['P2427']}]}],
#     'P213': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P213',
#        'hash': '6e2041001175ed7c7ae2905cdd24d273725e59f6',
#        'datavalue': {'value': '0000 0004 1936 9991', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q457281$B7C3FFB0-E6BA-44A4-AC58-262A2DEB4846',
#       'rank': 'normal',
#       'references': [{'hash': 'f20e7cc1dc95f8af90470df9ddea266baf12be00',
#         'snaks': {'P356': [{'snaktype': 'value',
#            'property': 'P356',
#            'hash': '39f2d847bb7bcfcba055cff1323f108b7bc3af66',
#            'datavalue': {'value': '10.6084/M9.FIGSHARE.4539889',
#             'type': 'string'},
#            'datatype': 'external-id'}]},
#         'snaks-order': ['P356']}]}],
#     'P3500': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P3500',
#        'hash': '405845dfd1a7d9bf66f9936f1fdc93427340ae11',
#        'datavalue': {'value': '14589', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q457281$79855EDB-211D-48A4-986E-77F4D9201526',
#       'rank': 'normal',
#       'references': [{'hash': '2834ac5da275724a6354a73d2d2a89ae956042a9',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '654ac97d41e766b6860b1b7acd87f11a6b00c4f9',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 64159407,
#              'id': 'Q64159407'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P248']}]}],
#     'P1315': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P1315',
#        'hash': '1f6ef06012264560284a203586c5be4171b3d18d',
#        'datavalue': {'value': '870187', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q457281$7AA81B0D-68FF-4358-9E1A-E436988AE4D0',
#       'rank': 'normal'}],
#     'P3793': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P3793',
#        'hash': '7d76dbb36a8b6c165ff57703bbbb248bc52658c6',
#        'datavalue': {'value': '2a03:b600:641::/107', 'type': 'string'},
#        'datatype': 'string'},
#       'type': 'statement',
#       'id': 'Q457281$F61A3ADD-EDB6-4C7E-97BB-56EB72786B13',
#       'rank': 'normal',
#       'references': [{'hash': '1b354d80bc3c1b47f031388e99c419fc35c94b19',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': 'ba4948b9b17639c36e0d62b1150c504cf05e9a64',
#            'datavalue': {'value': 'https://apps.db.ripe.net/search/lookup.html?source=ripe&key=2a03:b600:641::/107&type=inet6num',
#             'type': 'string'},
#            'datatype': 'url'}]},
#         'snaks-order': ['P854']}]}],
#     'P3876': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P3876',
#        'hash': '43c31721168263fd63368b5603275d3520d173e0',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 7002146,
#          'id': 'Q7002146'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q457281$2CAC4205-32DB-4867-9342-B6019CE92B63',
#       'rank': 'normal'}],
#     'P3417': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P3417',
#        'hash': '7697c276b74ae4b0d8c120cda49af850ac3426dc',
#        'datavalue': {'value': 'University-of-Illinois-at-Urbana-Champaign-2',
#         'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q457281$4c1426fa-4ef2-9f30-9000-3002aee2a434',
#       'rank': 'normal'}],
#     'P3984': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P3984',
#        'hash': '6b1af70b759dba0d574b615de9df2fa78c7e3909',
#        'datavalue': {'value': 'UIUC', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'qualifiers': {'P407': [{'snaktype': 'value',
#          'property': 'P407',
#          'hash': 'daf1c4fcb58181b02dff9cc89deb084004ddae4b',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 1860,
#            'id': 'Q1860'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P580': [{'snaktype': 'value',
#          'property': 'P580',
#          'hash': 'e321563030aa0763efaf8ab723d6c034f54a5058',
#          'datavalue': {'value': {'time': '+2008-08-07T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}],
#        'P1810': [{'snaktype': 'value',
#          'property': 'P1810',
#          'hash': '8fa48360ff0db8c127e2673cff78a9986612b826',
#          'datavalue': {'value': 'The University of Illinois at Urbana-Champaign',
#           'type': 'string'},
#          'datatype': 'string'}]},
#       'qualifiers-order': ['P407', 'P580', 'P1810'],
#       'id': 'Q457281$9b5bce88-4636-234a-11b0-eb364bddbbcf',
# ...
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 106509962,
#              'id': 'Q106509962'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P248']}]}],
#     'P3065': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P3065',
#        'hash': 'c8fed9d4a637f30ae1deee1e749f219c488c1f57',
#        'datavalue': {'value': '02-A024811695', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q457281$be254d2a-4a24-7d14-1eee-f51a757a43bd',
#       'rank': 'normal'}],
#     'P1015': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P1015',
#        'hash': '06489427983a0074ce9e2bcbecfc54aab9bb1986',
#        'datavalue': {'value': '90231602', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q457281$2b535bbc-4688-a42d-a611-ebabe3ccb3c1',
#       'rank': 'normal'}],
#     'P271': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P271',
#        'hash': '420ef70b3cfc10b1ff627ebffa1a2c3953e65719',
#        'datavalue': {'value': 'DA02840771', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q457281$e1b11d7e-4f0c-846e-d3e9-e7c436465c2f',
#       'rank': 'normal',
#       'references': [{'hash': 'ce743baf5dcb3a6e7af77ffb80e4f8d6ea7e9429',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': 'b09baac32eb0d06cecfd287182405f4371d8c4a2',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 115920372,
#              'id': 'Q115920372'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P11496': [{'snaktype': 'value',
#            'property': 'P11496',
#            'hash': '428644e97406b0ad7afbdc257313ef97153caa96',
#            'datavalue': {'value': '1140563741509614336', 'type': 'string'},
#            'datatype': 'external-id'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': '4ecd3d723f5acae5beaa5c8938ce818190fd570f',
#            'datavalue': {'value': {'time': '+2023-03-28T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P248', 'P11496', 'P813']}]}],
#     'P10227': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P10227',
#        'hash': '7c4ba17130bc988c618a405829e1a60c64fd91a1',
#        'datavalue': {'value': 'vtls001229901', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q457281$33ba219f-4ca1-b623-1e8b-7b3cb6ebeb62',
#       'rank': 'normal'}],
#     'P409': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P409',
#        'hash': '7195088104302e76388ee29ed4c25a3e091cf90b',
#        'datavalue': {'value': '35219078', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q457281$f029393b-4b6a-a0f3-1d5b-7841b992f932',
#       'rank': 'normal'}],
#     'P11496': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P11496',
#        'hash': '428644e97406b0ad7afbdc257313ef97153caa96',
#        'datavalue': {'value': '1140563741509614336', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q457281$22A549DB-947D-458E-8EAA-E2F9D08F3E15',
#       'rank': 'normal'}],
#     'P11686': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P11686',
#        'hash': 'cd481947bd718a4910eff7ea907a0f1d853aeafe',
#        'datavalue': {'value': '981058515098606706', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q457281$418E1CEE-9BCE-4196-83F3-825DD3F4AFA3',
#       'rank': 'normal'}],
#     'P6589': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P6589',
#        'hash': 'fb166a15e64995f99f9fb9efaed9b2ba7d4a93dc',
#        'datavalue': {'value': {'amount': '+3114979382',
#          'unit': 'http://www.wikidata.org/entity/Q4917'},
#         'type': 'quantity'},
#        'datatype': 'quantity'},
#       'type': 'statement',
#       'qualifiers': {'P585': [{'snaktype': 'value',
#          'property': 'P585',
#          'hash': '5334f6ac1879857ab8f6880e5ad63165d9fd1dcc',
#          'datavalue': {'value': {'time': '+2022-06-30T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'qualifiers-order': ['P585'],
#       'id': 'Q457281$81BAA715-2B51-4B92-BCB5-C0F73DC138CB',
#       'rank': 'normal',
#       'references': [{'hash': '52f1a7ecc6d38219777f3c3bab92045515d21b54',
#         'snaks': {'P50': [{'snaktype': 'value',
#            'property': 'P50',
#            'hash': '28f79a394936c7b9e32774108f54d8e0093f0a55',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 30268203,
#              'id': 'Q30268203'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': '6c705a54e32bd2245d5217eab268ab2f578b2184',
#            'datavalue': {'value': 'https://www.nacubo.org/Research/2022/Public-NTSE-Tables',
#             'type': 'string'},
#            'datatype': 'url'}],
#          'P1476': [{'snaktype': 'value',
#            'property': 'P1476',
#            'hash': 'af573ea01a1af4e7e1b428ffbe82ceebe61d6f64',
#            'datavalue': {'value': {'text': 'U.S. and Canadian 2022 NTSE Participating Institutions Listed by Fiscal Year 2022 Endowment Market Value, Change in Market Value from FY21 to FY22, and FY22 Endowment Market Values Per Full-time Equivalent Student (Excel)',
#              'language': 'en'},
#             'type': 'monolingualtext'},
#            'datatype': 'monolingualtext'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': '42205f66a4c9f5125fc912fac94c2893d641a108',
#            'datavalue': {'value': {'time': '+2023-05-13T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}],
#          'P577': [{'snaktype': 'value',
#            'property': 'P577',
#            'hash': '75981654f1111ae151da7d86c59bfddc4c1f6f8d',
#            'datavalue': {'value': {'time': '+2023-02-17T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P50', 'P854', 'P1476', 'P813', 'P577']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P6589',
#        'hash': '217cf7d8e0c7bbf752b13f4a4bc9070c2d4f0d32',
#        'datavalue': {'value': {'amount': '+3380331000',
#          'unit': 'http://www.wikidata.org/entity/Q4917'},
#         'type': 'quantity'},
#        'datatype': 'quantity'},
#       'type': 'statement',
#       'qualifiers': {'P585': [{'snaktype': 'value',
#          'property': 'P585',
#          'hash': '03cf40a96d32cc74be7b9c1ec5074ca82f7aa472',
#          'datavalue': {'value': {'time': '+2021-06-30T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'qualifiers-order': ['P585'],
#       'id': 'Q457281$8E403EFC-0195-48FB-96EE-70E8A5984B31',
#       'rank': 'normal',
#       'references': [{'hash': '52f1a7ecc6d38219777f3c3bab92045515d21b54',
#         'snaks': {'P50': [{'snaktype': 'value',
#            'property': 'P50',
#            'hash': '28f79a394936c7b9e32774108f54d8e0093f0a55',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 30268203,
#              'id': 'Q30268203'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': '6c705a54e32bd2245d5217eab268ab2f578b2184',
#            'datavalue': {'value': 'https://www.nacubo.org/Research/2022/Public-NTSE-Tables',
#             'type': 'string'},
#            'datatype': 'url'}],
#          'P1476': [{'snaktype': 'value',
#            'property': 'P1476',
#            'hash': 'af573ea01a1af4e7e1b428ffbe82ceebe61d6f64',
#            'datavalue': {'value': {'text': 'U.S. and Canadian 2022 NTSE Participating Institutions Listed by Fiscal Year 2022 Endowment Market Value, Change in Market Value from FY21 to FY22, and FY22 Endowment Market Values Per Full-time Equivalent Student (Excel)',
#              'language': 'en'},
#             'type': 'monolingualtext'},
#            'datatype': 'monolingualtext'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': '42205f66a4c9f5125fc912fac94c2893d641a108',
#            'datavalue': {'value': {'time': '+2023-05-13T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}],
#          'P577': [{'snaktype': 'value',
#            'property': 'P577',
#            'hash': '75981654f1111ae151da7d86c59bfddc4c1f6f8d',
#            'datavalue': {'value': {'time': '+2023-02-17T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P50', 'P854', 'P1476', 'P813', 'P577']}]}],
#     'P9756': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P9756',
#        'hash': 'd70fbdffbc235a9eb1f06532f86af06f9120eba5',
#        'datavalue': {'value': '11398', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q457281$E2DC87D5-E32B-4CC2-B36F-DA27BB5E42E5',
#       'rank': 'normal'}],
#     'P10588': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P10588',
#        'hash': '6148ff4792e2558dae8b852e132e0383886760ed',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 3955006,
#          'id': 'Q3955006'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q457281$D910B7B7-03A9-4851-9606-1C93FF073910',
#       'rank': 'normal',
#       'references': [{'hash': '9b48a6e47e9274d84316ecb85e75efc5d7e7b3ba',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '22dba446c343374a557c2077a4e85e3fbe932b5e',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 1966994,
#              'id': 'Q1966994'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P248']}]}]},
#    'sitelinks': {'arwiki': {'site': 'arwiki',
#      'title': 'جامعة إلينوي في إربانا-شامبين',
#      'badges': []},
#     'arzwiki': {'site': 'arzwiki',
#      'title': 'جامعة ايلينوى فى اوربانا-شامبين',
#      'badges': []},
#     'azbwiki': {'site': 'azbwiki',
#      'title': 'ایلینوی بیلیم\u200cیوردو، اربانا-شمپین',
#      'badges': []},
#     'azwiki': {'site': 'azwiki',
#      'title': 'Urbana-Şampeyn İllinoys Universiteti',
#      'badges': []},
#     'bgwiki': {'site': 'bgwiki',
#      'title': 'Университет на Илинойс в Ърбана-Шампейн',
#      'badges': []},
#     'bnwiki': {'site': 'bnwiki',
#      'title': 'ইউনিভার্সিটি অব ইলিনয় অ্যাট আর্বানা-শ্যাম্পেইন',
#      'badges': []},
#     'cawiki': {'site': 'cawiki',
#      'title': "Universitat d'Illinois a Urbana-Champaign",
#      'badges': []},
#     'ckbwiki': {'site': 'ckbwiki',
#      'title': 'زانکۆی ئیلینۆی لە ئێربانا–شەمپەین',
#      'badges': []},
#     'cswiki': {'site': 'cswiki',
#      'title': 'Univerzita Illinois v Urbana Champaign',
#      'badges': []},
#     'dewiki': {'site': 'dewiki',
#      'title': 'University of Illinois at Urbana-Champaign',
#      'badges': []},
#     'enwiki': {'site': 'enwiki',
#      'title': 'University of Illinois Urbana-Champaign',
#      'badges': []},
#     'eswiki': {'site': 'eswiki',
#      'title': 'Universidad de Illinois en Urbana-Champaign',
#      'badges': []},
#     'etwiki': {'site': 'etwiki', 'title': 'Illinoisi Ülikool', 'badges': []},
#     'fawiki': {'site': 'fawiki',
#      'title': 'دانشگاه ایلینوی اربانا-شمپین',
#      'badges': []},
#     'fiwiki': {'site': 'fiwiki',
#      'title': 'Illinoisin yliopisto, Urbana-Champaign',
#      'badges': []},
#     'frwiki': {'site': 'frwiki',
#      'title': "Université de l'Illinois à Urbana-Champaign",
#      'badges': []},
#     'hewiki': {'site': 'hewiki',
#      'title': 'אוניברסיטת אילינוי באורבנה-שמפיין',
#      'badges': []},
#     'idwiki': {'site': 'idwiki',
#      'title': 'Universitas Illinois Urbana-Champaign',
#      'badges': []},
#     'itwiki': {'site': 'itwiki',
#      'title': "Università dell'Illinois - Urbana-Champaign",
#      'badges': []},
#     'jawiki': {'site': 'jawiki', 'title': 'イリノイ大学アーバナ・シャンペーン校', 'badges': []},
#     'kowiki': {'site': 'kowiki', 'title': '일리노이 대학교 어배너-섐페인', 'badges': []},
#     'kywiki': {'site': 'kywiki',
#      'title': 'Иллинойс университети (Урбана-Шампейн)',
#      'badges': []},
#     'ltwiki': {'site': 'ltwiki',
#      'title': 'Ilinojaus universitetas Urbanoje-Šampeinėje',
#      'badges': []},
#     'mrwiki': {'site': 'mrwiki',
#      'title': 'युनिव्हर्सिटी ऑफ इलिनॉय अर्बाना-शॅम्पेन',
#      'badges': []},
#     'mswiki': {'site': 'mswiki',
#      'title': 'Universiti Illinois Urbana-Champaign',
#      'badges': []},
#     'ndswiki': {'site': 'ndswiki',
#      'title': 'University of Illinois at Urbana-Champaign',
#      'badges': []},
#     'nlwiki': {'site': 'nlwiki',
#      'title': 'Universiteit van Illinois te Urbana-Champaign',
#      'badges': []},
#     'plwiki': {'site': 'plwiki',
#      'title': 'Uniwersytet Illinois w Urbanie i Champaign',
#      'badges': []},
#     'pnbwiki': {'site': 'pnbwiki',
#      'title': 'یونیورسٹی آف الینوۓ',
#      'badges': []},
#     'ptwiki': {'site': 'ptwiki',
#      'title': 'Universidade de Illinois em Urbana-Champaign',
#      'badges': []},
#     'rowiki': {'site': 'rowiki',
#      'title': 'Universitatea Illinois, Urbana-Champaign',
#      'badges': []},
#     'ruwiki': {'site': 'ruwiki',
#      'title': 'Иллинойсский университет в Урбане-Шампейне',
#      'badges': []},
#     'ruwikinews': {'site': 'ruwikinews',
#      'title': 'Категория:Иллинойсский университет в Урбане-Шампейне',
#      'badges': []},
#     'simplewiki': {'site': 'simplewiki',
#      'title': 'University of Illinois Urbana-Champaign',
#      'badges': []},
#     'svwiki': {'site': 'svwiki',
#      'title': 'University of Illinois at Urbana-Champaign',
#      'badges': []},
#     'tawiki': {'site': 'tawiki',
#      'title': 'இலினொய் பல்கலைக்கழகம் (அர்பானா சாம்பேன்)',
#      'badges': []},
#     'thwiki': {'site': 'thwiki',
#      'title': 'มหาวิทยาลัยอิลลินอย เออร์แบนา-แชมเปญจน์',
#      'badges': []},
#     'tlwiki': {'site': 'tlwiki',
#      'title': 'Unibersidad ng Illinois, Urbana–Champaign',
#      'badges': []},
#     'trwiki': {'site': 'trwiki',
#      'title': 'University of Illinois at Urbana-Champaign',
#      'badges': []},
#     'ukwiki': {'site': 'ukwiki',
#      'title': 'Університет Іллінойсу в Урбана-Шампейн',
#      'badges': []},
#     'urwiki': {'site': 'urwiki',
#      'title': 'یونیورسٹی آف الینوائے ایٹ اوربانا–شیمپیئن',
#      'badges': []},
#     'xmfwiki': {'site': 'xmfwiki',
#      'title': 'ილინოისიშ უნივერსიტეტი (ურბანა-შამპეინი)',
#      'badges': []},
#     'zhwiki': {'site': 'zhwiki', 'title': '伊利诺伊大学厄巴纳-香槟分校', 'badges': []}}}},
#  'success': 1}

# %%
try:
    title = data['entities'][id_]['labels']['en']['value']
except:
    title = 'not found'
try:
    alternate_names = [v['value'] for v in data['entities'][id_]['aliases']['en']]
except:
    alternate_names = 'not found'
try:
    description = data['entities'][id_]['descriptions']['en']['value'] 
except:
    description = 'not found'
try:
    twitter = data['entities'][id_]['claims']['P2002'][0]['mainsnak']['datavalue']['value']
except:
    twitter = 'not found'
try:
    facebook = data['entities'][id_]['claims']['P2013'][0]['mainsnak']['datavalue']['value']
except:
    facebook = 'not found'
try:
    instagram = data['entities'][id_]['claims']['P2003'][0]['mainsnak']['datavalue']['value']
except:
    instagram = 'not found'
try:
    subreddit = data['entities'][id_]['claims']['P3984'][0]['mainsnak']['datavalue']['value']
except:
    subreddit = 'not found'
try:
    official_websites = [v['mainsnak']['datavalue']['value']for v in data['entities'][id_]['claims']['P856']]
except:
    official_websites = 'not found'
try:
    logo_file = data['entities'][id_]['claims']['P154'][0]['mainsnak']['datavalue']['value'].replace(' ', '_')
    logo_image_url = f'www.wikidata.org/wiki/{id_}#/media/File:{logo_file}'
except:
    logo_image_url = 'not found'
try:
    campus_file = data['entities'][id_]['claims']['P18'][0]['mainsnak']['datavalue']['value'].replace(' ', '_')
    campus_image_url = f'www.wikidata.org/wiki/{id_}#/media/File:{campus_file}'
except:
    campus_image_url = 'not found'
    pass
 


result = {
    'wikidata_id': id_,
    'title': title,
    'description': description,
    'alternate_names': alternate_names,
    'twitter': twitter,
    'facebook': facebook,
    'instagram': instagram,
    'subreddit': subreddit,
    'official_websites': official_websites,
    'logo_image_url': logo_image_url,
    'campus_image_url': campus_image_url
}
 
result
# Out:
# {'wikidata_id': 'Q457281',
#  'title': 'University of Illinois at Urbana–Champaign',
#  'description': 'public research university in Urbana and Champaign, Illinois, United States',
#  'alternate_names': ['UIUC',
#   'U of I',
#   'University of Illinois at Urbana',
#   'University of Illinois at Champaign',
#   'University of Illinois at Champaign-Urbana',
#   'University of Illinois at Urbana-Champaign',
#   'University of Illinois',
#   'U. of I.',
#   'uiuc.edu',
#   'University of Illinois Urbana-Champaign',
#   'University of Illinois, Urbana-Champaign'],
#  'twitter': 'Illinois_Alma',
#  'facebook': 'illinois.edu',
#  'instagram': 'illinois1867',
#  'subreddit': 'UIUC',
#  'official_websites': ['https://illinois.edu/'],
#  'logo_image_url': 'www.wikidata.org/wiki/Q457281#/media/File:University_of_Illinois_at_Urbana–Champaign_logo.svg',
#  'campus_image_url': 'www.wikidata.org/wiki/Q457281#/media/File:UIUC_Illini_Union_and_Main_Quad.jpg'}

# %%
def call_wikidata_api(query):
    params = {
        'action': 'wbsearchentities',
        'format': 'json',
        'search': query,
        'language': 'en'
    }
    json_data = fetch_wikidata(params).json()
    id_ = json_data['search'][0]['id']
    params = {
        'action': 'wbgetentities',
        'ids': id_, 
        'format': 'json',
        'languages': 'en'
    }

    data = fetch_wikidata(params).json()
    try:
        title = data['entities'][id_]['labels']['en']['value']
    except:
        title = 'not found'
    try:
        alternate_names = [v['value'] for v in data['entities'][id_]['aliases']['en']]
    except:
        alternate_names = 'not found'
    try:
        description = data['entities'][id_]['descriptions']['en']['value'] 
    except:
        description = 'not found'
    try:
        twitter = data['entities'][id_]['claims']['P2002'][0]['mainsnak']['datavalue']['value']
    except:
        twitter = 'not found'
    try:
        facebook = data['entities'][id_]['claims']['P2013'][0]['mainsnak']['datavalue']['value']
    except:
        facebook = 'not found'
    try:
        instagram = data['entities'][id_]['claims']['P2003'][0]['mainsnak']['datavalue']['value']
    except:
        instagram = 'not found'
    try:
        subreddit = data['entities'][id_]['claims']['P3984'][0]['mainsnak']['datavalue']['value']
    except:
        subreddit = 'not found'
    try:
        official_websites = [v['mainsnak']['datavalue']['value']for v in data['entities'][id_]['claims']['P856']]
    except:
        official_websites = 'not found'
    try:
        logo_file = data['entities'][id_]['claims']['P154'][0]['mainsnak']['datavalue']['value'].replace(' ', '_')
        logo_image_url = f'www.wikidata.org/wiki/{id_}#/media/File:{logo_file}'
    except:
        logo_image_url = 'not found'
    try:
        campus_file = data['entities'][id_]['claims']['P18'][0]['mainsnak']['datavalue']['value'].replace(' ', '_')
        campus_image_url = f'www.wikidata.org/wiki/{id_}#/media/File:{campus_file}'
    except:
        campus_image_url = 'not found'
 
    result = {
        'wikidata_id': id_,
        'title': title,
        'description': description,
        'alternate_names': alternate_names,
        'twitter': twitter,
        'facebook': facebook,
        'instagram': instagram,
        'subreddit': subreddit,
        'official_websites': official_websites,
        'logo_image_url': logo_image_url,
        'campus_image_url': campus_image_url
    }
    return result

# %%
res = call_wikidata_api('uc berkeley')

# %%
url = res['logo_image_url']
url
# Out:
# 'www.wikidata.org/wiki/Q168756#/media/File:Seal_of_University_of_California,_Berkeley.svg'

# %%
res2 = call_wikidata_api('uiuc')
url2 = res2['logo_image_url']
url2
# Out:
# 'www.wikidata.org/wiki/Q457281#/media/File:University_of_Illinois_at_Urbana–Champaign_logo.svg'

# %%
from bs4 import BeautifulSoup
import urllib

# %%
page = urllib.request.urlopen('https://' + url3)
soup = BeautifulSoup(page)
images = soup.findAll('img')
for image in images:
    print('https:' + image['src'])
    print()
# Out:
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9c/University_of_Illinois_at_Urbana%E2%80%93Champaign_logo.svg/220px-University_of_Illinois_at_Urbana%E2%80%93Champaign_logo.svg.png
#
# https://upload.wikimedia.org/wikipedia/commons/thumb/6/6a/UIUC_Illini_Union_and_Main_Quad.jpg/220px-UIUC_Illini_Union_and_Main_Quad.jpg
#
# https:https://maps.wikimedia.org/img/osm-intl,13,40.110538888889,-88.228411111111,310x180.png?lang=en&domain=www.wikidata.org&title=Q457281&groups=_d105d0fc75d31cc26a2b5f8565a10c37691b6b10
#
# https:https://maps.wikimedia.org/img/osm-intl,13,40.09609,-88.21953,310x180.png?lang=en&domain=www.wikidata.org&title=Q457281&groups=_3958062c04ff59f5638dd0a0d0a3d0002bae9f7a
#
# https:https://maps.wikimedia.org/img/osm-intl,13,40.1163,-88.22632,310x180.png?lang=en&domain=www.wikidata.org&title=Q457281&groups=_bdd1061f5847500eb2d5616abdc07d28afa93451
#
# https:https://maps.wikimedia.org/img/osm-intl,13,40.091080555556,-88.226319444444,310x180.png?lang=en&domain=www.wikidata.org&title=Q457281&groups=_dbef7b280ca84a3c9b047d6aee7606b54274eb0f
#
# https:https://maps.wikimedia.org/img/osm-intl,13,40.096088888889,-88.244088888889,310x180.png?lang=en&domain=www.wikidata.org&title=Q457281&groups=_0ff383232207865614449806d803d982ca28f341
#
# https://www.wikidata.org/wiki/Special:CentralAutoLogin/start?type=1x1
#
# https:/static/images/footer/wikimedia-button.png
#
# https:/static/images/footer/poweredby_mediawiki_88x31.png
